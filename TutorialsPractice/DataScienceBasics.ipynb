# %%
x = [1, 2, 3, 4, 5, 6]
len(x)
# Out:
# 6

# %%
x[-2:]
# Out:
# [5, 6]

# %%
x[:3]
# Out:
# [1, 2, 3]

# %%
x[:]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x.append(2)

# %%
x[:]
# Out:
# [1, 2, 3, 4, 5, 6, 2]

# %%
dict = {}
dict['satyajit'] = 'ghana'
dict['firstname'] = 'lastname'

# %%
dict.get('satyajit')
# Out:
# 'ghana'

# %%
for firstname in dict:
    print(firstname + ':' + dict[firstname])
# Out:
# satyajit:ghana
# firstname:lastname

# %%
print((lambda x: x * x * x)(3))
# Out:
# 27

# %%
import numpy as np

# %%
incomes = np.random.gamma(27000, 15000, 10000)
np.mean(incomes)
# Out:
# 405018978.77239424

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(incomes, 50)
plt.show()

# %%
incomes.std()
# Out:
# 2425552.6967438427

# %%
x = np.arange(-3, 3, 0.001)

# %%
plt.xkcd()
plt.figure(figsize=(10, 8))
plt.plot(x, np.sin(x) * np.cos(2*x), '--',linewidth=4.0)
plt.plot(x, np.sin(x) * np.exp(x), linewidth=2.0)
plt.grid()
plt.show()

# %%
plt.xkcd()
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
plt.xticks([])
plt.yticks([])
ax.set_ylim([-30, 10])
data = np.ones(100)
data[70:] -= np.arange(30)

plt.annotate("The Day i realized\n i could make by own \nIce-Cream",
            xy=(70, 1), arrowprops=dict(arrowstyle='->'), xytext=(15, -10))

plt.plot(data)

plt.xlabel('time')
plt.ylabel('my overall health')
# Out:
# Text(0,0.5,'my overall health')

# %%
dict.values
# Out:
# <method 'values' of 'dict' objects>

# %%
x, y = np.meshgrid(np.linspace(-3, 3, 10), np.linspace(-3, 3, 10))

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# # Multivariate Regression

# %%
import pandas as pd

# %%
df = pd.read_excel('http://cdn.sundog-soft.com/Udemy/DataScience/cars.xls')

# %%
df.head()
# Out:
#           Price  Mileage   Make    Model      Trim   Type  Cylinder  Liter  \
# 0  17314.103129     8221  Buick  Century  Sedan 4D  Sedan         6    3.1
# 1  17542.036083     9135  Buick  Century  Sedan 4D  Sedan         6    3.1
# 2  16218.847862    13196  Buick  Century  Sedan 4D  Sedan         6    3.1
# 3  16336.913140    16342  Buick  Century  Sedan 4D  Sedan         6    3.1
# 4  16339.170324    19832  Buick  Century  Sedan 4D  Sedan         6    3.1
#
#    Doors  Cruise  Sound  Leather
# 0      4       1      1        1
# 1      4       1      1        0
# 2      4       1      1        0
# 3      4       1      0        0
# 4      4       1      0        1

# %%
import statsmodels.api as sm

df['Model_ord'] = pd.Categorical(df.Model).codes
X = df[['Mileage', 'Model_ord', 'Doors']]
y = df[['Price']]

X1 = sm.add_constant(X)
est1 = sm.OLS(y, X1).fit()

est.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.042
# Model:                            OLS   Adj. R-squared:                  0.038
# Method:                 Least Squares   F-statistic:                     11.57
# Date:                Thu, 01 Nov 2018   Prob (F-statistic):           1.98e-07
# Time:                        22:38:29   Log-Likelihood:                -8519.1
# No. Observations:                 804   AIC:                         1.705e+04
# Df Residuals:                     800   BIC:                         1.706e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.125e+04   1809.549     17.272      0.000    2.77e+04    3.48e+04
# ...

# %%
y.groupby(df.Doors).mean()
# Out:
#               Price
# Doors
# 2      23807.135520
# 4      20580.670749
